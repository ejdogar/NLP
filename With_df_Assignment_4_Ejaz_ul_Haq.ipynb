# %% [markdown]
# <a href="https://colab.research.google.com/github/ejdogar/NLP/blob/main/With_df_Assignment_4_Ejaz_ul_Haq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dataset = pd.read_csv("/content/drive/MyDrive/Atomcamp/Assignments/Assignment-4/Pak Suzuki Car Reviews.csv")
dataset.head()
# Out:
#    Unnamed: 0                               Model  Overall_rating  \
# 0           0                   2023 Suzuki Bolan               1
# 1           1           2022 Suzuki Swift GLX CVT               4
# 2           2  2022 Suzuki Cultus Auto Gear Shift               5
# 3           3         2007 Suzuki Liana RXi (CNG)               5
# 4           4                 2022 Suzuki Alto VX               4
#
#             Date                                             Review  Style  \
# 0   Nov 30, 2023  \nis gadi k baray me 3 lafaz kahunga 1 bakwaaa...      1
# 1   Nov 29, 2023  \nA good looking car with best fuel ? economy,...      5
# 2   Nov 26, 2023  \nfor me i would must buy because its will sav...      5
# 3   Nov 12, 2023  \nI have used it for more than 5 years. litera...      5
# 4   Nov 09, 2023  \nExterior: 10/10 on design but the quality us...      5
#
#    Comfort  Fuel_Economy  Performance  Value_for_Money
# 0        1             1            1                1
# 1        4             5            4                5
# 2        5             5            5                5
# 3        5             5            5                5
# 4        5             5            4                5

# %% [markdown]
# # Step 1: Data Preprocessing

# %% [markdown]
# #### 1.1 Converting Date Column to DateTime Format

# %%
dataset["Year"] = pd.to_datetime(dataset["Date"]).dt.year
dataset.drop("Date", axis=1, inplace = True)
dataset.head()
# Out:
#    Unnamed: 0                               Model  Overall_rating  \
# 0           0                   2023 Suzuki Bolan               1
# 1           1           2022 Suzuki Swift GLX CVT               4
# 2           2  2022 Suzuki Cultus Auto Gear Shift               5
# 3           3         2007 Suzuki Liana RXi (CNG)               5
# 4           4                 2022 Suzuki Alto VX               4
#
#                                               Review  Style  Comfort  \
# 0  \nis gadi k baray me 3 lafaz kahunga 1 bakwaaa...      1        1
# 1  \nA good looking car with best fuel ? economy,...      5        4
# 2  \nfor me i would must buy because its will sav...      5        5
# 3  \nI have used it for more than 5 years. litera...      5        5
# 4  \nExterior: 10/10 on design but the quality us...      5        5
#
#    Fuel_Economy  Performance  Value_for_Money  Year
# 0             1            1                1  2023
# 1             5            4                5  2023
# 2             5            5                5  2023
# 3             5            5                5  2023
# 4             5            4                5  2023

# %% [markdown]
# #### 1.2 Creating a Year Column
# Splitting the Model Column into Model Name and Year Column, in order to enhance model answering capability.

# %% [markdown]
# #### 1.3 Formatting our reviews

# %%
dataset["Review"] = dataset["Review"].str.replace("\n", "")
dataset.head()
# Out:
#    Unnamed: 0                               Model  Overall_rating  \
# 0           0                   2023 Suzuki Bolan               1
# 1           1           2022 Suzuki Swift GLX CVT               4
# 2           2  2022 Suzuki Cultus Auto Gear Shift               5
# 3           3         2007 Suzuki Liana RXi (CNG)               5
# 4           4                 2022 Suzuki Alto VX               4
#
#                                               Review  Style  Comfort  \
# 0  is gadi k baray me 3 lafaz kahunga 1 bakwaaas ...      1        1
# 1  A good looking car with best fuel ? economy,Dr...      5        4
# 2  for me i would must buy because its will save ...      5        5
# 3  I have used it for more than 5 years. literall...      5        5
# 4  Exterior: 10/10 on design but the quality used...      5        5
#
#    Fuel_Economy  Performance  Value_for_Money  Year
# 0             1            1                1  2023
# 1             5            4                5  2023
# 2             5            5                5  2023
# 3             5            5                5  2023
# 4             5            4                5  2023

# %%
import re
for index, review in enumerate(dataset['Review']):
  review = re.sub("[?.,$]", " ", review)
  dataset["Review"][index] = review
dataset.head()
# Out:
# <ipython-input-5-2636c59a88a7>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset["Review"][index] = review
#    Unnamed: 0                               Model  Overall_rating  \
# 0           0                   2023 Suzuki Bolan               1
# 1           1           2022 Suzuki Swift GLX CVT               4
# 2           2  2022 Suzuki Cultus Auto Gear Shift               5
# 3           3         2007 Suzuki Liana RXi (CNG)               5
# 4           4                 2022 Suzuki Alto VX               4
#
#                                               Review  Style  Comfort  \
# 0  is gadi k baray me 3 lafaz kahunga 1 bakwaaas ...      1        1
# 1  A good looking car with best fuel   economy Dr...      5        4
# 2  for me i would must buy because its will save ...      5        5
# 3  I have used it for more than 5 years  literall...      5        5
# 4  Exterior: 10/10 on design but the quality used...      5        5
#
#    Fuel_Economy  Performance  Value_for_Money  Year
# 0             1            1                1  2023
# 1             5            4                5  2023
# 2             5            5                5  2023
# 3             5            5                5  2023
# 4             5            4                5  2023

# %% [markdown]
# #### 1.4 Dropping Unnamed Column
# As this column just have indexes and is of no significance as we have system indexing available for out dataset.

# %%
dataset.drop("Unnamed: 0", axis=1, inplace=True)
dataset.head()
# Out:
#                                 Model  Overall_rating  \
# 0                   2023 Suzuki Bolan               1
# 1           2022 Suzuki Swift GLX CVT               4
# 2  2022 Suzuki Cultus Auto Gear Shift               5
# 3         2007 Suzuki Liana RXi (CNG)               5
# 4                 2022 Suzuki Alto VX               4
#
#                                               Review  Style  Comfort  \
# 0  is gadi k baray me 3 lafaz kahunga 1 bakwaaas ...      1        1
# 1  A good looking car with best fuel   economy Dr...      5        4
# 2  for me i would must buy because its will save ...      5        5
# 3  I have used it for more than 5 years  literall...      5        5
# 4  Exterior: 10/10 on design but the quality used...      5        5
#
#    Fuel_Economy  Performance  Value_for_Money  Year
# 0             1            1                1  2023
# 1             5            4                5  2023
# 2             5            5                5  2023
# 3             5            5                5  2023
# 4             5            4                5  2023

# %% [markdown]
# 1.5 Coverting Rating from Numbers to Wrod Representation

# %%
rating_dic = {1: "Worst", 2: "Bad", 3: "Average", 4: "Good", 5: "Excellent"}
dataset[["Overall_rating", "Style", "Comfort", "Fuel_Economy", "Performance", "Value_for_Money"]] = dataset[["Overall_rating",  "Style", "Comfort", "Fuel_Economy", "Performance", "Value_for_Money"]].applymap(rating_dic.get)
dataset.head()
# Out:
#                                 Model Overall_rating  \
# 0                   2023 Suzuki Bolan          Worst
# 1           2022 Suzuki Swift GLX CVT           Good
# 2  2022 Suzuki Cultus Auto Gear Shift      Excellent
# 3         2007 Suzuki Liana RXi (CNG)      Excellent
# 4                 2022 Suzuki Alto VX           Good
#
#                                               Review      Style    Comfort  \
# 0  is gadi k baray me 3 lafaz kahunga 1 bakwaaas ...      Worst      Worst
# 1  A good looking car with best fuel   economy Dr...  Excellent       Good
# 2  for me i would must buy because its will save ...  Excellent  Excellent
# 3  I have used it for more than 5 years  literall...  Excellent  Excellent
# 4  Exterior: 10/10 on design but the quality used...  Excellent  Excellent
#
#   Fuel_Economy Performance Value_for_Money  Year
# 0        Worst       Worst           Worst  2023
# 1    Excellent        Good       Excellent  2023
# 2    Excellent   Excellent       Excellent  2023
# 3    Excellent   Excellent       Excellent  2023
# 4    Excellent        Good       Excellent  2023

# %%
dataframe = dataset.astype(str)
dataframe.head()
dataframe["Year"].astype(int)
# Out:
# 0       2023
# 1       2023
# 2       2023
# 3       2023
# 4       2023
#         ...
# 1094    2009
# 1095    2009
# 1096    2009
# 1097    2009
# 1098    2009
# Name: Year, Length: 1099, dtype: int64

# %% [markdown]
# ### Importing Necessary Libraries For Our Model

# %%
# ! pip install accelerate==0.21.0 peft==0.4.0 bitsandbytes==0.40.2 transformers==4.30.2 langchain chromadb --quiet
# ! pip install tiktoken --quiet
# ! pip install sentence_transformers lark auto-gptq optimum --quiet

# %% [markdown]
# # Step 2: Creating Data Chunk From our CSV File

# %%
from langchain.document_loaders import DataFrameLoader
# loader = DataFrameLoader(dataframe, page_content_column="Model")
loader = DataFrameLoader(dataframe, page_content_column="Model")
documents = loader.load()
documents[0].page_content
# Out:
# '2023 Suzuki Bolan'

# %%
documents[0]
# Out:
# Document(page_content='2023 Suzuki Bolan', metadata={'Overall_rating': 'Worst', 'Review': 'is gadi k baray me 3 lafaz kahunga 1 bakwaaas 2 bakwaaaaaaas 3 bakwaaaassaaaaaaaaasfazool tareen or gharya tareen gadi shame on Suzuki company dunya me har cheez badal gai comfort level kahan se kahan ponch gya par ye farsoooda gadi he koi isko lyne ka sochy bhi na', 'Style': 'Worst', 'Comfort': 'Worst', 'Fuel_Economy': 'Worst', 'Performance': 'Worst', 'Value_for_Money': 'Worst', 'Year': '2023'})

# %% [markdown]
# # Step 3: Creating Embeddings of Our Chunks
# Generating Embaddings based on our above created chunks.

# %%
# from huggingface_hub import notebook_login
# notebook_login()

# %%
from langchain.embeddings import HuggingFaceBgeEmbeddings

model_name = "google/flan-t5-base"
model_kwargs = {"device": "cuda"}
encode_kwargs = {"normalize_embeddings": True}
embeddings = HuggingFaceBgeEmbeddings(
    model_name=model_name, model_kwargs=model_kwargs, encode_kwargs=encode_kwargs
)
# Out:
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name /root/.cache/torch/sentence_transformers/google_flan-t5-base. Creating a new one with MEAN pooling.

# %%
# !pip install chromadb

# %%
from langchain.vectorstores import Chroma
db = Chroma.from_documents(documents, embeddings, persist_directory = "./llama-db1")

# %%
import torch
import transformers
from langchain import HuggingFacePipeline
from langchain import PromptTemplate, LLMChain
from transformers import AutoTokenizer, AutoModelForCausalLM, AutoModel, GPTQConfig

# %%
tokenizer = AutoTokenizer.from_pretrained("TheBloke/llama-2-7b-Chat-GPTQ")
tokenizer.pad_token = tokenizer.eos_token
quantization_config_loading = GPTQConfig(bits=4, disable_exllama=True, tokenizer=tokenizer)
model = AutoModelForCausalLM.from_pretrained("TheBloke/Llama-2-7b-Chat-GPTQ",
                              quantization_config=quantization_config_loading,
                              device_map="auto"
                        )
# Out:
# Using `disable_exllama` is deprecated and will be removed in version 4.37. Use `use_exllama` instead and specify the version with `exllama_config`.The value of `use_exllama` will be overwritten by `disable_exllama` passed in `GPTQConfig` or stored in your config file.
# You passed `quantization_config` to `from_pretrained` but the model you're loading already has a `quantization_config` attribute and has already quantized weights. However, loading attributes (e.g. ['use_cuda_fp16', 'use_exllama', 'max_input_length', 'exllama_config', 'disable_exllama']) will be overwritten with the one you passed to `from_pretrained`. The rest will be ignored.

# %%
from transformers import pipeline
import torch
from langchain.llms import HuggingFacePipeline

pipe = pipeline("text-generation",
                model=model,
                tokenizer= tokenizer,
                torch_dtype=torch.bfloat16,
                device_map="auto",
                max_new_tokens = 256,
                do_sample=True,
                top_k=1,
                num_return_sequences=1,
                eos_token_id=tokenizer.eos_token_id,
                repetition_penalty=1.2
                )

llm=HuggingFacePipeline(pipeline=pipe, model_kwargs={'temperature':0})

# %%
print(llm(prompt="What are the reviews regarding Suzuki Alto in year 2016?"))
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# A: The Suzuki Alto is a popular subcompact car that has been around since 1974. In 2016, the Alto received positive reviews for its fuel efficiency, affordability, and reliability. Here are some of the reviews from reputable sources:
# * Car and Driver gave the 2016 Suzuki Alto a rating of 5 out of 10, praising its fuel economy but criticizing its lackluster performance and limited features.
# * Kelley Blue Book awarded the Alto with an overall score of 4.3 out of 5, citing its excellent fuel economy, spacious interior, and low price point as major advantages. However, they also noted that the Alto's engine can be noisy and underpowered at times.
# * Edmunds gave the 2016 Suzuki Alto a rating of B+, highlighting its impressive fuel economy and affordability while noting that it may not offer enough features to appeal to more discerning buyers.
# * Consumer Reports rated the Alto 4 out of 5, praising its fuel efficiency and value for money

# %%
from langchain.chains import RetrievalQA

rag = RetrievalQA.from_chain_type(
        llm=llm, chain_type='stuff',
        retriever=db.as_retriever()
        )

# %%
print(rag("What are the reviews regarding Suzuki Alto in year 2016?")["result"])
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#  I can provide information on Suzuki Alto models from different years based on your query. However, since you have mentioned "in year 2016," I will give you a brief overview of what people had to say about Suzuki Alto in that particular year.
# In 2016, Suzuki Alto received mixed reviews from critics and consumers alike. Some praised its fuel efficiency, spacious interior, and affordability, while others criticized its lackluster performance, outdated design, and limited features compared to other vehicles in its class. Here are some specific reviews for reference:
# * CarAndBike: In their review of the Suzuki Alto, they noted that it was a good option for those looking for a basic car with decent fuel economy but felt that its engine was underpowered and the ride quality could be better. They gave it a rating of 3.5/5 stars.
# * The Hindu Business Line: This publication tested the Suzuki Alto and found it to be a reliable and efficient vehicle but noted that its interiors were not as premium as those of its competitors. They also observed that the car's handling was not
